# %%
import requests  
import pandas as pd
import numpy as np

# %% [markdown]
# Сделаем запрос на информацию о пользователе, id которого равен 1:

# %%
token = '730f1c64730f1c64730f1c643d701f67fe7730f730f1c641005942620f4461043d96904'
url = 'https://api.vk.com/method/users.get'   
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'}  
   
response = requests.get(url, params=params)  
response.text
# Out:
# '{"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}'

# %%
first_user = response.json()['response'][0]
first_user
# Out:
# {'id': 1,
#  'bdate': '10.10.1984',
#  'sex': 2,
#  'first_name': 'Павел',
#  'last_name': 'Дуров',
#  'can_access_closed': True,
#  'is_closed': False}

# %% [markdown]
# Попробуем информацию о нескольких пользователях:

# %%
token = '730f1c64730f1c64730f1c643d701f67fe7730f730f1c641005942620f4461043d96904'
url = 'https://api.vk.com/method/users.get'   
ids = str([x for x in range(11)])

params = {'user_ids': ids, 
          'v': 5.95, 
          'fields': 'sex,bdate', 
          'access_token': token, 
          'lang': 'ru'}  
   
response = requests.get(url, params=params)  
response.json()['response']
# Out:
# [{'id': 1,
#   'bdate': '10.10.1984',
#   'sex': 2,
#   'first_name': 'Павел',
#   'last_name': 'Дуров',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 2,
#   'sex': 1,
#   'first_name': 'Александра',
#   'last_name': 'Владимирова',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 3,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 4,
#   'sex': 0,
#   'deactivated': 'deleted',
#   'first_name': 'DELETED',
#   'last_name': ''},
#  {'id': 5,
#   'bdate': '18.11',
#   'sex': 2,
#   'first_name': 'Илья',
#   'last_name': 'Перекопский',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 6,
#   'sex': 2,
#   'first_name': 'Николай',
#   'last_name': 'Дуров',
#   'can_access_closed': True,
#   'is_closed': False},
#  {'id': 7,
#   'sex': 2,
#   'first_name': 'Алексей',
#   'last_name': 'Кобылянский',
#   'can_access_closed': False,
#   'is_closed': True},
#  {'id': 8,
#   'sex': 2,
# ...

# %% [markdown]
# Попробуем определить процентное соотношкние мужчин и женщин у первых 500 пользователей сети:

# %%
url = 'https://api.vk.com/method/users.get'
token = "730f1c64730f1c64730f1c643d701f67fe7730f730f1c641005942620f4461043d96904"
params = {'user_ids': ids, 
          'v': 5.95, 
          'fields': 'sex', 
          'access_token': token, 
          'lang': 'ru'}
ids = str([x for x in range(500)])

df = pd.DataFrame(requests.get(url, params = params).json()['response'])

df
# Out:
#    id  sex  first_name    last_name can_access_closed is_closed deactivated
# 0   1    2       Павел        Дуров              True     False         NaN
# 1   2    1  Александра  Владимирова             False      True         NaN
# 2   3    0     DELETED                            NaN       NaN     deleted
# 3   4    0     DELETED                            NaN       NaN     deleted
# 4   5    2        Илья  Перекопский              True     False         NaN
# 5   6    2     Николай        Дуров              True     False         NaN
# 6   7    2     Алексей  Кобылянский             False      True         NaN
# 7   8    2         Аки   Сепиашвили              True     False         NaN
# 8   9    1       Настя    Васильева             False      True         NaN

# %% [markdown]
# У некоторых пользователей не указан пол, учитывать их не будем

# %%
df[df.sex != 0]['sex'].value_counts(normalize = True)
# Out:
# 2    0.714286
# 1    0.285714
# Name: sex, dtype: float64

# %% [markdown]
# Мужчин, как оказалось, больше

# %% [markdown]
# Попробуем проанализировать официальную группу ВКонтакте:

# %%
url = 'https://api.vk.com/method/groups.getMembers'  
params = {  
    'group_id': 'vk',  
    'v': 5.95,  
    'access_token': token  
}  
response = requests.get(url, params = params)  
data = response.json()  
print(data)  
 
len(data['response']['items'])
# Out:
# {'response': {'count': 12929155, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 943, 952, 958, 966, 976, 979, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1301, 1333, 1334, 1336, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2136, 2150, 2195, 2201, 2230, 2236, 2273, 2281, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2513, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2896, 2909, 2919, 2922, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3172
# ...

# %% [markdown]
# Видим, что количество подписчиков группы близко к 13 миллионам, а нам выдало лишь 1000 значений
#
# Это максимум, который может отдать API за один раз
#
# Для обхода лимита используем offset:

# %% [markdown]
# При работе с API ВКонтакте я сталкивался с KeyError, к сожалению, не понимаю почему, но try-except помогают

# %%
max_count = 100000
count = 1000  
offset = 0  
user_ids = [] 
url = 'https://api.vk.com/method/groups.getMembers'  
token = "730f1c64730f1c64730f1c643d701f67fe7730f730f1c641005942620f4461043d96904"

while offset < max_count:  
    try:    
        print('Выгружаю {} пользователей с offset = {}'.format(count, offset))     
        params = {  
            'group_id': 'vk',  
            'v': 5.95,  
            'count': count,  
            'offset': offset,  
            'access_token': token  
        } 
        r = requests.get(url, params = params)  
        data = r.json()
        user_ids += data['response']['items']   

        offset += count  
    except KeyError:
        continue
user_idsс
# Out:
# Выгружаю 1000 пользователей с offset = 0
# Выгружаю 1000 пользователей с offset = 1000
# Выгружаю 1000 пользователей с offset = 1000
# Выгружаю 1000 пользователей с offset = 2000
# Выгружаю 1000 пользователей с offset = 3000
# Выгружаю 1000 пользователей с offset = 4000
# Выгружаю 1000 пользователей с offset = 5000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 6000
# Выгружаю 1000 пользователей с offset = 7000
# Выгружаю 1000 пользователей с offset = 8000
# Выгружаю 1000 пользователей с offset = 9000
# Выгружаю 1000 пользователей с offset = 10000
# ...

# %% [markdown]
# Позже, я подумал о том, что запросы могут выполняться довольно быстро, поэтому попробовал немного изменить код:

# %%
import time

max_count = 100000
count = 1000  
offset = 0  
user_ids = [] 
url = 'https://api.vk.com/method/groups.getMembers'  
token = "730f1c64730f1c64730f1c643d701f67fe7730f730f1c641005942620f4461043d96904"

while offset < max_count:  
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))     
    params = {  
        'group_id': 'vk',  
        'v': 5.95,  
        'count': count,  
        'offset': offset,  
        'access_token': token  
    } 
    r = requests.get(url, params = params)  
    data = r.json()
    user_ids += data['response']['items']   

    offset += count  
    time.sleep(0.5)
user_ids

# %% [markdown]
# Результат аналогичный

# %% [markdown]
# Ещё одна полезная вещь, которую можно получить,  —  это количество взаимодействий с постами через API новостной ленты. Рассмотримм последние 10 постов группы. Мы продолжаем работать с группой https://vk.com/vk.
#
# Начнем с  формирования запроса к API ВКонтакте методом wall.get():

# %%
params = {  
    'domain': 'vk',  
    'filter': 'owner',  
    'count': 10,  
    'offset': 0,  
    'access_token': token,  
    'v': 5.95  
}  
url = 'https://api.vk.com/method/wall.get'
response = requests.get(url, params = params)

response.json()['response']['items'][0]

# %% [markdown]
# Ещё одна полезная вещь, которую можно получить, — это количество взаимодействий с постами через API новостной ленты. На данном этапе будем использовать самый простой вариант: берем последние 10 постов группы. Мы продолжаем работать с группой https://vk.com/vk.
#
# Начнем с формирования запроса к API ВКонтакте методом wall.get():

# %%
def get_smm_index(short_name, token):
    
    params = {  
        'group_id': short_name,  
        'v': 5.95,  
        'count': 1,  
        'offset': 0,  
        'access_token': token  
    } 

    r = requests.get('https://api.vk.com/method/groups.getMembers', params = params)  
    counter = r.json()['response']['count']

    params = {
        'domain': short_name,  
        'filter': 'owner',  
        'count': 10,  
        'offset': 0,  
        'access_token': token,  
        'v': 5.95 
    }
    response = requests.get('https://api.vk.com/method/wall.get', params = params)
    data = response.json()['response']['items']
    total_number = 0
    
    for i in range(len(data)):
        total_number += data[i]['likes']['count'] + data[i]['comments']['count'] + data[i]['reposts']['count']
        
    return total_number/counter

# %%
get_smm_index('vk', token)
# Out:
# 0.008286608255098122
